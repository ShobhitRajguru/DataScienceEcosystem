# %%
import numpy as np

# %%
data1 = np.random.chisquare(df = 1, size = 1000)
data2 = np.random.chisquare(df = 2, size = 1000)
data3 = np.random.chisquare(df = 3, size = 1000)

# %%
print(data1[:10])
# Out:
# [0.0148635  0.33149025 1.79517043 1.62346793 0.12327047 0.32436336
#  0.98447634 0.5798234  0.71530151 0.05920003]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.distplot(data1, hist = False, label = 'dof 1')
sns.distplot(data2, hist = False, label = 'dof 2')
sns.distplot(data3, hist = False, label = 'dof 3')
plt.legend()
# Out:
# C:\Users\Shobhit Rajguru\AppData\Local\Temp\ipykernel_26556\327745576.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1, hist = False, label = 'dof 1')
# C:\Users\Shobhit Rajguru\AppData\Local\Temp\ipykernel_26556\327745576.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2, hist = False, label = 'dof 2')
# C:\Users\Shobhit Rajguru\AppData\Local\Temp\ipykernel_26556\327745576.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data3, hist = False, label = 'dof 3')

# %%
from scipy.stats import chi2_contingency

# %%
data = [[10,20,30],[6,9,17]]

# %%
stat,p_value,dof,chi_array = chi2_contingency(data)

# %%
p_value
# Out:
# 0.873028283380073

# %%
data = [[10,20,30],[9,1,8]]

# %%
stat,p_value,dof,chi_array = chi2_contingency(data)

# %%
p_value
# Out:
# 0.005595003173072841
